# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3])
y=np.array([3,4,5])

# %%
plt.subplot(4,3,1)
plt.plot(x,y, c='green')
plt.subplot(4,3,5)
plt.plot(x,y, c='yellow')
plt.subplot(4,3,9)
plt.plot(x,y, c='orange')
